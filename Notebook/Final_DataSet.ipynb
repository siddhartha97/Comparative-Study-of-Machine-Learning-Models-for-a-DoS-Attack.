# %%
import warnings
import numpy as np
import pandas as pd
warnings.filterwarnings("ignore")

# %%
df1 = pd.read_csv('Received_Packets.csv')

df2 = pd.read_csv('collision_rate.csv')

df3 = pd.read_csv('Proba.csv')

# %%
df1 = df1.set_index('Node')
df2 = df2.set_index('Node')
df3 = df3.set_index('Node')

# %%
df = pd.concat([df1,df2,df3],axis = 1)

# %%
df
# Out:
#       Received Rate  Collision_rate  Probability
# Node
# 1        112.215777        0.542801     0.319698
# 2          5.300208        0.589468     0.023945
# 3          3.313069        0.209308     0.032219
# 4        136.733099        0.874332     0.057649
# 5          3.947448        0.473441     0.027551
# 6          2.791449        0.162091     0.025253
# 7         69.970389        0.501621     0.468814
# 8          2.502249        0.035197     0.000000
# 9          6.275025        0.672883     0.034029
# 10        15.973573        0.326387     0.003657
# 11         3.652256        0.417231     0.020408
# 12         1.626176        0.016651     0.004957
# 13         4.187119        0.300089     0.059163
# 14         3.786332        0.283977     0.065426
# 15       139.309865        0.680912     0.000896
# 16         5.771468        0.608408     0.067016
# 17         5.300081        0.606399     0.023945
# 18         4.941504        0.535881     0.026091
# ...

# %%
df.to_csv('FinalDataset.csv')
