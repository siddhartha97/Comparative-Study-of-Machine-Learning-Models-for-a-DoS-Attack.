# %%
import warnings
import numpy as np
import pandas as pd
warnings.filterwarnings("ignore")

# %%
df1 = pd.read_csv('../Columns/col1.txt',sep='delimiter',header=None)
df2 = pd.read_csv('../Columns/col2.txt',sep='delimiter',header=None)
df3 = pd.read_csv('../Columns/col3.txt',sep='delimiter',header=None)
df4 = pd.read_csv('../Columns/col4.txt',sep='delimiter',header=None)
df5 = pd.read_csv('../Columns/col5.txt',sep='delimiter',header=None)
df6 = pd.read_csv('../Columns/col6.txt',sep='delimiter',header=None)
df7 = pd.read_csv('../Columns/col7.txt',sep='delimiter',header=None)
df8 = pd.read_csv('../Columns/col8.txt',sep='delimiter',header=None)
df9 = pd.read_csv('../Columns/col9.txt',sep='delimiter',header=None)
df10 = pd.read_csv('../Columns/col10.txt',sep='delimiter',header=None)
df11 = pd.read_csv('../Columns/col11.txt',sep='delimiter',header=None)
df12 = pd.read_csv('../Columns/col12.txt',sep='delimiter',header=None)
df13 = pd.read_csv('../Columns/col13.txt',sep='delimiter',header=None)
df14 = pd.read_csv('../Columns/col14.txt',sep='delimiter',header=None)
df15 = pd.read_csv('../Columns/col15.txt',sep='delimiter',header=None)
df16 = pd.read_csv('../Columns/col16.txt',sep='delimiter',header=None)
df17 = pd.read_csv('../Columns/col17.txt',sep='delimiter',header=None)
df18 = pd.read_csv('../Columns/col18.txt',sep='delimiter',header=None)
df19 = pd.read_csv('../Columns/col19.txt',sep='delimiter',header=None)
df20 = pd.read_csv('../Columns/col20.txt',sep='delimiter',header=None)
df21 = pd.read_csv('../Columns/col21.txt',sep='delimiter',header=None)
df22 = pd.read_csv('../Columns/col22.txt',sep='delimiter',header=None)
df23 = pd.read_csv('../Columns/col23.txt',sep='delimiter',header=None)
df24 = pd.read_csv('../Columns/col24.txt',sep='delimiter',header=None)
df25 = pd.read_csv('../Columns/col25.txt',sep='delimiter',header=None)

# %%
df1.columns = ["Packet Info"]
df2.columns = ["Time Stamp"]
df3.columns = ["Node"]
df4.columns = ["Trace Level"]
df5.columns = ["Column5"]
df6.columns = ["Unique Id"]
df7.columns = ["PayLoad Type"]
df8.columns = ["Bytes"]
df9.columns = ["Source Mac Address"]
df10.columns = ["Destination Mac Address"]
df11.columns = ["Column11"]
df12.columns = ["IP Packet"]
df13.columns = ["Column13"]
df14.columns = ["Column14"]
df15.columns = ["Column15"]
df16.columns = ["Column16"]
df17.columns = ["Column17"]
df18.columns = ["Column18"]
df19.columns = ["Column19"]
df20.columns = ["Column20"]
df21.columns = ["Column21"]
df22.columns = ["Column22"]
df23.columns = ["Column23"]
df24.columns = ["Column24"]
df25.columns = ["Column25"]

# %%
frames = [df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12,df13,df14,df15,df16,df17,df18,df19,df20,df21,df22,df23,df24,df25]

# %%
df = pd.concat(frames,axis=1)

# %%
df.head()
# Out:
#   Packet Info  Time Stamp  Node Trace Level Column5 Unique Id PayLoad Type  \
# 0           s    3.000000  _15_         AGT     ---         0          tcp
# 1           r    3.000000  _15_         RTR     ---         0          tcp
# 2           s    3.000000  _15_         RTR     ---         0         AODV
# 3           s    3.000395  _15_         MAC     ---         0         AODV
# 4           r    3.000915  _41_         MAC     ---         0         AODV
#
#   Bytes Source Mac Address Destination Mac Address    ...     Column16  \
# 0    40                 [0                       0    ...           32
# 1    40                 [0                       0    ...           32
# 2    48                 [0                       0    ...           30
# 3   106                 [0                ffffffff    ...           30
# 4    48                 [0                ffffffff    ...           30
#
#   Column17 Column18 Column19 Column20 Column21 Column22 Column23 Column24  \
# ...

# %%
#Removed the unwanted stuffs from the following columns
df["Node"] = df["Node"].replace('_','',regex=True).astype(float)
df["Source Mac Address"] = df["Source Mac Address"].replace("\\[",'',regex=True).astype(str)
df["IP Packet"] = df["IP Packet"].replace("\\]",'',regex=True).astype(str)
df["Column14"] = df["Column14"].replace("\\[",'',regex=True).astype(str)
df["Column17"] = df["Column17"].replace("\\]",'',regex=True).astype(str)
df["Column18"] = df["Column18"].replace("\\[",'',regex=True).astype(str)
df["Column19"] = df["Column19"].replace("\\]",'',regex=True).astype(str)
df["Column21"] = df["Column21"].replace("\\[",'',regex=True).astype(str)
df["Column22"] = df["Column22"].replace("\\]",'',regex=True).astype(str)
df["Column23"] = df["Column23"].replace("\\[",'',regex=True).astype(str)
df["Column24"] = df["Column24"].replace("\\]",'',regex=True).astype(str)
#df.drop(["Column5","Column13"],axis = 1,inplace = True)
df = df.fillna(0)

# %%
df.head(25)
# Out:
#    Packet Info  Time Stamp  Node Trace Level Column5 Unique Id PayLoad Type  \
# 0            s    3.000000  15.0         AGT     ---         0          tcp
# 1            r    3.000000  15.0         RTR     ---         0          tcp
# 2            s    3.000000  15.0         RTR     ---         0         AODV
# 3            s    3.000395  15.0         MAC     ---         0         AODV
# 4            r    3.000915  41.0         MAC     ---         0         AODV
# 5            r    3.000915  13.0         MAC     ---         0         AODV
# 6            r    3.000915  27.0         MAC     ---         0         AODV
# 7            r    3.000915  14.0         MAC     ---         0         AODV
# 8            r    3.000915  34.0         MAC     ---         0         AODV
# 9            r    3.000915  20.0         MAC     ---         0         AODV
# 10           r    3.000916  30.0         MAC     ---         0         AODV
# ...

# %% [markdown]
# # calculating collision rate

# %%
filter_by_col = df[df['Column5']=='COL'].groupby('Node')
#col_rate = filter_by_col
time = filter_by_col['Time Stamp'].max() - filter_by_col['Time Stamp'].min()
collision_rate = filter_by_col.size()/time
collision_rate = pd.DataFrame(collision_rate,columns=['Collision_rate'])

# %%
collision_rate.to_csv('collision_rate.csv')

# %%
collision_rate
# Out:
#       Collision_rate
# Node
# 0.0         2.033473
# 1.0         1.087628
# 2.0         0.597571
# 3.0         0.221620
# 4.0         2.816396
# 5.0         0.545968
# 6.0         0.184661
# 7.0         1.545153
# 8.0         0.035197
# 9.0         0.689000
# 10.0        0.400932
# 11.0        0.423307
# 12.0        0.016651
# 13.0        0.406832
# 14.0        0.390720
# 15.0        2.220013
# 16.0        0.662802
# 17.0        0.616472
# 18.0        0.543940
# 19.0        0.417281
# 20.0        0.938795
# 21.0        0.171840
# 22.0        0.106821
# 23.0        0.492228
# 24.0        0.043397
# 25.0        0.224817
# 26.0        0.564087
# 27.0        0.422954
# 28.0        0.086178
# 29.0        0.554012
# 30.0        1.087874
# 31.0        0.263927
# 32.0        0.047880
# 33.0        0.024981
# 34.0        1.781268
# 35.0        1.202718
# 36.0        0.335399
# 37.0        0.533869
# 38.0        0.106118
# 39.0        0.751449
# 41.0        0.751229
# 42.0        0.491560
# ...

# %% [markdown]
# # calculating received rate

# %%
received = df[df['Packet Info'] == 'r']
received = received[['Time Stamp','Node']]
group_node = df.groupby('Node')

received_packets = group_node.size()
time = group_node['Time Stamp'].max() - group_node['Time Stamp'].min()
received_rate = received_packets/time

# %%
received_rate = pd.DataFrame(received_rate)

# %%
received_rate = received_rate.rename(columns = {0:'Received Rate'})

# %%
received_rate
# Out:
#       Received Rate
# Node
# 0.0      230.051720
# 1.0      224.396872
# 2.0        5.394891
# 3.0        3.560794
# 4.0      336.490415
# 5.0        4.930282
# 6.0        3.288915
# 7.0      173.687532
# 8.0        2.552617
# 9.0        8.428477
# 10.0      29.572559
# 11.0       3.763053
# 12.0       1.648342
# 13.0       6.019865
# 14.0       5.030988
# 15.0     278.852727
# 16.0       6.871313
# 17.0       5.378645
# 18.0       5.020069
# 19.0       3.636249
# 20.0      22.070463
# 21.0       2.993730
# 22.0       1.046903
# 23.0       4.284786
# 24.0       2.008648
# 25.0       2.760259
# 26.0       5.042228
# 27.0       6.400512
# 28.0       2.453132
# 29.0       4.726072
# 30.0      63.314164
# 31.0       2.707856
# 32.0       2.093261
# 33.0       2.282648
# 34.0     277.119223
# 35.0      96.070295
# 36.0       4.631664
# 37.0       5.396775
# 38.0       3.206393
# 39.0      10.958102
# 40.0       0.235437
# 41.0      37.629693
# 42.0       4.282912
# 43.0     184.085050
# ...

# %%
received_rate.to_csv('Received Packets.csv')
