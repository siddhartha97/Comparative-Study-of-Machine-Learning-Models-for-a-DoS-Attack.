# %%
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('Finalset.csv',index_col='node')

# %%
df = df.ix[:,1:]

# %%
sns.regplot(df["Collision_rate"],df["Probability"])

# %%
df1 = df[df["Collision_rate"] < 1]
df2 = df1[df1["Received Rate"] < 100]

# %%
sns.regplot(df2["Received Rate"],df2["Probability"])

# %%
sns.regplot(df2["Collision_rate"],df2["Probability"])

# %%
final = df2

# %%
X = final[["Collision_rate","Received Rate"]]
Y = final["Probability"]

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size = 0.4,random_state=1)

# %%
sns.distplot(y_train)

# %%
array = np.arange(0,0.4,0.1)
accuracy = []

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score,accuracy_score

# %%
temp_y_train = np.array(y_train)
temp_x_train  = np.array(x_train)

temp_y_test = np.array(y_test)
temp_x_test  = np.array(x_test)
